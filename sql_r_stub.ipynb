# %%
library(sqldf)
require(stats)
require(lattice)

db <- dbConnect(SQLite(), dbname="~/Data/yahoo.db")

sql <- 'SELECT * FROM aav_prices WHERE symbol = "BNS"'
price_df <- dbGetQuery(db, sql);

# %%
price_df
# Out:
#     symbol Date       Open  High  Low   Close Adj Close Volume
# 1   BNS    2018-09-26 77.15 77.92 77.15 77.58 NA        2817300
# 2   BNS    2018-09-27 77.72 78.12 77.63 77.68 NA        1746000
# 3   BNS    2018-09-28 77.69 77.69 76.91 76.99 NA        2634700
# 4   BNS    2018-10-01 76.99 77.15 75.78 76.19 NA        1905200
# 5   BNS    2018-10-02 76.05 76.08 75.23 75.49 NA        2113400
# 6   BNS    2018-10-03 75.69 75.81 75.29 75.47 NA        1917000
# 7   BNS    2018-10-04 75.39 75.54 74.64 75.08 NA        3024600
# 8   BNS    2018-10-05 75.09 75.64 75.00 75.27 NA        2137700
# 9   BNS    2018-10-09 75.12 75.20 74.40 74.49 NA        2575300
# 10  BNS    2018-10-10 74.36 74.71 73.83 73.83 NA        2390200
# 11  BNS    2018-10-11 73.35 73.40 71.97 71.99 NA        5477600
# 12  BNS    2018-10-12 72.94 72.94 71.46 71.71 NA        3933000
# 13  BNS    2018-10-15 71.94 71.94 71.08 71.10 NA        2314300
# 14  BNS    2018-10-16 71.38 71.83 70.99 71.83 NA        2366800
# ...
